# %% [markdown]
# <a href="https://colab.research.google.com/github/NikGonsales/Python_Course/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head(10)
# Out:
#   whoAmI
# 0  robot
# 1  human
# 2  robot
# 3  human
# 4  robot
# 5  human
# 6  human
# 7  human
# 8  human
# 9  robot

# %%
# Метод get_dummies
pd.get_dummies(data['whoAmI']).head(10)
# Out:
#    human  robot
# 0      0      1
# 1      1      0
# 2      0      1
# 3      1      0
# 4      0      1
# 5      1      0
# 6      1      0
# 7      1      0
# 8      1      0
# 9      0      1

# %%
# Без метода get_dummies
pd.DataFrame({'human': data['whoAmI'] == 'human',
              'robot': data['whoAmI'] == 'robot'}).astype(int).head(10)
# Out:
#    human  robot
# 0      0      1
# 1      1      0
# 2      0      1
# 3      1      0
# 4      0      1
# 5      1      0
# 6      1      0
# 7      1      0
# 8      1      0
# 9      0      1
